# %%
# load model
from keras.models import load_model
import numpy as np
model = load_model('lstm_model_1029.h5')

# %%
# generate test data
test_data = np.random.uniform(1000,2000,(10,30,5))

# %%
test_data[1]
# Out:
# array([[1400.99391208, 1622.19536859, 1011.5886513 , 1347.69205002,
#         1282.33545838],
#        [1388.78790041, 1003.4121254 , 1594.17717501, 1351.66592437,
#         1261.91138651],
#        [1748.77005859, 1909.08756182, 1097.64019792, 1287.98304099,
#         1781.3713069 ],
#        [1807.8130618 , 1040.21553668, 1297.88519457, 1678.4368947 ,
#         1356.29669323],
#        [1106.50623901, 1606.29926332, 1073.86721079, 1487.09196912,
#         1503.98158185],
#        [1907.44909487, 1254.41599447, 1385.30540405, 1082.07646627,
#         1636.09309584],
#        [1990.10099211, 1441.67710963, 1288.57355974, 1406.88028621,
#         1891.5204305 ],
#        [1441.22597349, 1016.29137677, 1969.22545681, 1054.79423935,
#         1951.37917632],
#        [1331.22240288, 1565.85974228, 1706.18686536, 1769.82327793,
#         1767.84069282],
#        [1263.25458032, 1804.53892494, 1640.00577369, 1151.48265843,
#         1693.56936409],
# ...

# %%
model.predict(test_data)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([[1638.9902],
#        [1349.0693],
#        [1473.8982],
#        [1549.5355],
#        [1355.2269],
#        [1677.6202],
#        [1551.0068],
#        [1622.7101],
#        [1404.5443],
#        [1462.4617]], dtype=float32)
